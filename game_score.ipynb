# %%
#To know the Average Score

# %%
player_name = input("enter your name: ")
games_played = int(input("enter number of games you had played: "))
total_score = int(input("enter total score: "))
average_score = total_score / games_played
print(f"the average is {average_score}")
# Out:
# enter your name: sai
# enter number of games you had played: 38
# enter total score: 1288
# the average is 33.89473684210526
